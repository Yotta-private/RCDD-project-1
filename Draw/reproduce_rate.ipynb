# %%
import seaborn as sns
import pandas as pd
import matplotlib.pyplot as plt 
import numpy as np

# %%
# x = [1,2,3,4,5]
# sns.set_style('ticks', {'font.family':'serif', 'font.serif':'Times New Roman'})

plt.figure(figsize=(8, 6))
x = [1,5,10,15,20,30,40,50]
y = [1968/30747,4042/30747,6175/30747,7215/30747,7900/30747,8700/30747,9200/30747,9500/30747]
plt.plot(x,y,'b-',linewidth=3,ms=7, alpha=0.9,marker='D', mfc='black',color = "black")
plt.tick_params(labelsize='medium', width=3)
# plt.xticks([1,5,10,25,50])
# plt.xticks(x, label)
plt.ylim(0,0.5)
plt.xlim(0,55)
# for i,j in zip(x,y):
#     plt.annotate(str(j),xy=(i+0.5,j-2.8),fontsize=15)
    
# plt.annotate(str(57.19),xy=(50-1,57.19+1))
plt.tick_params(labelsize=18)
sns.despine()
plt.xlabel(u'Epochs',fontsize=18)

plt.ylabel('RPP',fontsize=20)  
plt.savefig('RPP-EPOCH',dpi = 300)

# %%
sns.set_style('ticks', {'font.family':'serif', 'font.serif':'Times New Roman'})

plt.figure(figsize=(8, 6))
x = [1,5,10,15,20,30,40,50]
y = [56996,63118,61403,59722,57914,54022,51216,47691]
plt.plot(x,y,'b-',linewidth=3,ms=7, alpha=0.9,marker='D', mfc='black',color = "black")
plt.tick_params(labelsize='medium', width=3)
# plt.xticks([1,5,10,25,50])
# plt.xticks(x, label)
plt.ylim(40000,70000)
plt.xlim(0,52)
# for i,j in zip(x,y):
#     plt.annotate(str(j),xy=(i+0.5,j-2.8),fontsize=15)
    
# plt.annotate(str(57.19),xy=(50-1,57.19+1))
plt.tick_params(labelsize=12)
sns.despine()
plt.xlabel(u'Epochs',fontsize=18)

plt.ylabel('Unique Scaffolds',fontsize=18)  
plt.savefig('Diversity-EPOCH',dpi = 300)

# %%
# x = [1,2,3,4,5]
sns.set_style('ticks', {'font.family':'serif', 'font.serif':'Times New Roman'})

plt.figure(figsize=(8, 6))
x = [1,5,10,25,50,100]
y = [5.81,25.80,35.66,49.20,57.19, 63.9]
plt.plot(x,y,'b-',linewidth=3,ms=7, alpha=0.9,marker='D', mfc='black',color = "black")
plt.tick_params(labelsize='medium', width=3)
# plt.xticks([1,5,10,25,50])
# plt.xticks(x, label)
plt.ylim(0,71)
plt.xlim(0,105,20)
for i,j in zip(x,y):
    plt.annotate(str(j),xy=(i+0.5,j-2.8),fontsize=15)
    
# plt.annotate(str(57.19),xy=(50-1,57.19+1))
plt.tick_params(labelsize=15)
sns.despine()
plt.xlabel(u'PCL Size',fontsize=18)

plt.ylabel('RPP%',fontsize=18)  
plt.savefig('repetition',dpi = 300)

# %%
plt.plot(loss9 ,'bo-',label = '90') 
plt.plot(loss8 ,'rd-',label = '80%') 
plt.plot(loss7 ,'gs-',label = '70%') 
plt.legend((u'90%', u'80%',u'70%'),loc='best',fontsize='x-large')
plt.xlabel('Epochs',fontsize=20)

plt.ylabel('Loss',fontsize=20)  

# plt.title('Train Loss')
plt.xticks(np.arange(0, 22,2))

plt.xlim(0,21)
plt.tick_params(labelsize='medium', width=3)

plt.tick_params(labelsize=18)
sns.despine()
plt.savefig('Train-loss-9-1',dpi = 300)
