# %%
import seaborn as sns
import pandas as pd

import matplotlib.pyplot as plt 
import numpy as np
sns.set(style="ticks", palette="muted", color_codes=True)
df_gen = pd.read_table( './oringin/gensca')
df_train = pd.read_table( './oringin/cv2sca')
df_div = pd.read_table( 'dataset.txt')
# df=df1.join(df2.np)
# sns.distplot( df[df.cat == 'DIV'].np)
# sns.distplot( df[df.cat == 'NAT'].np)
# ,columns=["smi", "score"]

# %%
df_gen.head(5)
# Out:
#   CNC[C@H](C)CCCCCC(=O)CC(=O)/C=C/c1cc(OC)c(O)cc1Cc1cnc(N)c(Cc2cccc(CO)c2)c1  \
# 0  COCCNC(=O)NC[C@H]1C[C@@H]2CCN1C[C@@H]2c1cc(-c2...
# 1  Cc1ccc(C(=O)NC[C@H]2C[C@@H]3CCN2C[C@@H]3CN2CCC...
# 2  COC[C@]1(O)[C@H]2C[C@@]3([C@H](C)CC[C@@]3(O)[C...
# 3  CCC1(/C=C2\OC(=O)C3=C2CC[C@H]2[C@@H]4CC[C@@]5(...
# 4  C=C1C(=O)O[C@H]2/C=C(/C)[C@@H](O)C[C@H]3O[C@]3...
#
#    1.442
# 0 -1.674
# 1 -0.838
# 2  3.466
# 3  3.184
# 4  3.354

# %%
df_score = df_sort.iloc[:50,1]
df_score.to_csv('50_score.csv',index = None)

# %%
df_sort = df_gen.sort_values(by="1.442",ascending=False)
print(df_sort.head(20))
df_pre = df_sort.iloc[:50,0]
df_score = df_sort.iloc[0,:50]
df_pre.to_csv('50_structure.csv',index = None)
# Out:
#        CNC[C@H](C)CCCCCC(=O)CC(=O)/C=C/c1cc(OC)c(O)cc1Cc1cnc(N)c(Cc2cccc(CO)c2)c1  \
# 23116   CC1=CC(=O)[C@H](O)[C@@]2(C)[C@H]1C[C@H]1OC(=O)...
# 77824   CC1=CC(=O)[C@@H](O)[C@@]2(C)[C@H]1C[C@H]1OC(=O...
# 62402   CC1=CC(=O)[C@@H](O)[C@]2(C)[C@H]1C[C@H]1OC(=O)...
# 144024  C=C1[C@H](O)[C@@]23C[C@H]1CC[C@H]2[C@@]12CO[C@...
# 110726  C=C1[C@H]2CC[C@H]3[C@@]45CO[C@](O)([C@@H](O)[C...
# 16298   C=C1[C@@H]2CC[C@H]3[C@@]45CO[C@](O)([C@@H](O)[...
# 133501                           C=C[C@H](O)C#CC#C/C=C\CO
# 71862                            C=C[C@H](O)C#CC#C/C=C/CO
# 121222  CC1(C)CC[C@@H](O)[C@@]2(C)[C@@H]1[C@H]1C[C@](C...
# 72587   C=C1C(=O)[C@]23C[C@H]1CC[C@H]2[C@@]12CO[C@]3(O...
# 145035  C=C1C(=O)[C@]23C[C@H]1C[C@H](O)[C@H]2[C@]12CO[...
# 29446   C=C1C(=O)[C@]23C[C@H]1C[C@H](O)[C@H]2[C@@]12CO...
# 30924   C=C1C(=O)[C@]23[C@H]4O[C@H]5O[C@]2(O)[C@@H](O)...
# 75724                             C=C[C@H](O)C#CC#C/C=C/C
# 29910   C=C1[C@@H]2C[C@@H](O)[C@@H]3[C@](C2)(C(=O)O[C@...
# ...

# %%
from rdkit import Chem
from rdkit import rdBase
from rdkit.Chem import AllChem
from rdkit import DataStructs

from rdkit.Chem import AllChem
from rdkit.Chem import Draw
# a = str(df_pre.iloc[27,0])
# m1 = Chem.MolFromSmiles(a)
# AllChem.Compute2DCoords(m1)
# Draw.MolToImage(m1)
generated = Chem.SmilesMolSupplier('preten_50.csv')
smi = []
for m in generated: smi.append(Chem.MolToSmiles(m))
print(smi[0])
mols = []
for s in smi: mols.append(Chem.MolFromSmiles(s)) 

for m in mols: tmp= AllChem.Compute2DCoords(m)
    
Draw.MolsToGridImage(mols,molsPerRow=3,subImgSize=(250,250))
# Out:
# CC1=CC(=O)C(O)C2(C)C1CC1OC(=O)C(O)C3C(C)C(O)C4(O)OCC13C42
# <PIL.Image.Image image mode=RGBA size=750x4250 at 0x7F35BAA49E10>

# %%
w = Chem.SDWriter('foo_test.sdf')

for m in mols: w.write(m)

# %%
plt.figure(figsize=(8, 6))
sns.distplot(df_gen.iloc[:,1],color='b',label = 'Generated set')
sns.distplot(df_train.iloc[:,1],color='r',label ='Training set' )
sns.distplot(df_div.iloc[:,1],color='g',hist=False)
plt.legend(('Generated set','Training set','NIH-Diversity set'),loc='best',fontsize=14)
plt.xlabel('NP-Score',fontsize=17)  
plt.ylabel('Distribution',fontsize=17) 
plt.tick_params(labelsize='medium', width=3)
plt.tick_params(labelsize=15)
plt.xticks(np.arange(-4, 5.5,1))
sns.despine()
plt.savefig('NP-sore',dpi = 300)
# Out:
# /home/zhengsj/.conda/envs/py36/lib/python3.6/site-packages/matplotlib/axes/_axes.py:6462: UserWarning: The 'normed' kwarg is deprecated, and has been replaced by the 'density' kwarg.
#   warnings.warn("The 'normed' kwarg is deprecated, and has been "

# %%
sns.distplot(df1[80000:].score)
sns.distplot(df2.score)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-d02dca50d532> in <module>()
# ----> 1 sns.distplot(df1[80000:].score)
#       2 sns.distplot(df2.score)
#
# NameError: name 'sns' is not defined

# %%
sns.distplot(df1[10000:].score)
sns.distplot(df2.score)
# Out:
# /home/zhengsj/.conda/envs/py36/lib/python3.6/site-packages/matplotlib/axes/_axes.py:6462: UserWarning: The 'normed' kwarg is deprecated, and has been replaced by the 'density' kwarg.
#   warnings.warn("The 'normed' kwarg is deprecated, and has been "
