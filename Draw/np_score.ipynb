# %%
import seaborn as sns
import pandas as pd

import matplotlib.pyplot as plt 
import numpy as np
sns.set(style="ticks", palette="muted", color_codes=True)
df_gen = pd.read_table( 'generated.csv')
df_train = pd.read_table( 'train_score.csv')
df_div = pd.read_table( 'biolike-zinc.txt')
df_div1 = pd.read_table( 'dataset.txt')
# df=df1.join(df2.np)
# sns.distplot( df[df.cat == 'DIV'].np)
# sns.distplot( df[df.cat == 'NAT'].np)

# %%
a = df_gen.iloc[50000:,1].mean()
a1 = df_gen.iloc[50000:,1].std()
b = df_train.iloc[50000:,1].mean()
b1 = df_train.iloc[50000:,1].std()
c = df_div.iloc[:,1].mean()
c1 = df_div.iloc[:,1].std()
print(a,a1,b,b1,c,c1)
# Out:
# 1.0893116827784797 1.465654955098716 1.223105084626606 1.5556219343579936 -1.2452603878116344 0.6034245205940457

# %%
a = np.array(df_div1.iloc[:,1])
a= list(a)
listc = []
for x in a:
    x = int(x)
    listc.append(x)

# %%
sns.set(style="ticks")


k=0
listk=[]
for i in range(1,99000,19000):
        score = df_div1.iloc[k:i,1].mean()
        k= i
        listk.append(score)

# %%
plt.plot(listk[ 1:],color='b',label ='Generated set')

# %%
sns.set(style="ticks",font="Times New Roman")
sns.color_palette("hls", 10)
plt.style.use('default')

plt.figure(figsize=(8, 6))
sns.distplot(df_gen.iloc[50000:,1],color='blue', hist_kws={"color": "blue","alpha": 0.68},label ='Generated set')
sns.distplot(df_train.iloc[50000:,1],color='red',hist_kws={"color": "red","alpha": 0.68},label ='Training set' )
sns.distplot(df_div.iloc[:,1],color='green',hist_kws={"color": "green","alpha": 0.68}, label ='ZINC-Biogenic-like' )
# sns.distplot(df_div1.iloc[:,1],color='c',label ='NIH-Diversity set' )
plt.legend(('PCL','ZBL','ZLL'),loc='best',fontsize=14)
plt.xlabel('NP-likeness Score',fontsize=17)  
plt.ylabel('Normalized Frequency',fontsize=17) 
plt.tick_params(labelsize='medium', width=3)
plt.tick_params(labelsize=15)
plt.xticks(np.arange(-4, 5.5,1))
plt.yticks(np.arange(0, 0.85,0.1))
sns.despine()
plt.savefig('NP-sore',dpi = 300)
# Out:
# /home/zhengsj/.conda/envs/py36/lib/python3.6/site-packages/matplotlib/axes/_axes.py:6462: UserWarning: The 'normed' kwarg is deprecated, and has been replaced by the 'density' kwarg.
#   warnings.warn("The 'normed' kwarg is deprecated, and has been "

# %%
sns.distplot(df1[80000:].score)
sns.distplot(df2.score)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-d02dca50d532> in <module>()
# ----> 1 sns.distplot(df1[80000:].score)
#       2 sns.distplot(df2.score)
#
# NameError: name 'sns' is not defined

# %%
sns.distplot(df1[10000:].score)
sns.distplot(df2.score)
# Out:
# /home/zhengsj/.conda/envs/py36/lib/python3.6/site-packages/matplotlib/axes/_axes.py:6462: UserWarning: The 'normed' kwarg is deprecated, and has been replaced by the 'density' kwarg.
#   warnings.warn("The 'normed' kwarg is deprecated, and has been "
